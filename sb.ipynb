# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %%
options = Options()
options.add_argument('--headless')

# %%
driver = webdriver.Chrome(options=options)

# %%
driver.get("https://github.com/")

# %%
print(driver.page_source)
print(driver.current_url)
# Out:
# <html lang="en" data-a11y-animated-images="system" data-turbo-loaded=""><head><style type="text/css">.turbo-progress-bar {
#   position: fixed;
#   display: block;
#   top: 0;
#   left: 0;
#   height: 3px;
#   background: #0076ff;
#   z-index: 2147483647;
#   transition:
#     width 300ms ease-out,
#     opacity 150ms 150ms ease-in;
#   transform: translate3d(0, 0, 0);
# }
# </style>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin="">
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
# ...

# %%
h1 = driver.find_element(By.CLASS_NAME, 'color-fg-muted')

# %%
h1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0569bd420e337a075c55a4b27639e3be", element="E00D99F4EBBAC26F9EF2FDED07F2C9EE_element_15")>

# %%
driver = webdriver.Chrome()
driver.get("https://www.naukri.com/data-scientist-jobs?k=data%20scientist")

# %%
info_fleft = driver.find_elements(By.CLASS_NAME,'info.fleft')
for i in range(len(info_fleft)):
    print(info_fleft[i].text)
    # new = []
    # new = driver.find_elements(By.CLASS_NAME, 'title.ellipsis')
# Out:
# Data Science Specialist
# Accenture
# 4.1
# 35560 Reviews
# Data Scientist - R/Python
# Okda Solutions
# Data Scientist_NLP
# Fractal Analytics
# 4.1
# 402 Reviews
# Data Science Analyst - Data Science
# Accenture
# 4.1
# 35560 Reviews
# Data Science Analyst Data Science
# Accenture
# 4.1
# 35560 Reviews
# Analytics Specialist - Artificial Intelligence Innovation
# Accenture
# 4.1
# 35560 Reviews
# Senior Data Scientist
# Walmart
# 4.1
# 1629 Reviews
# Data Scientist, Engineering at Google
# Blob Infotech
# Machine Learning (AI) Architect
# Persistent
# 4.0
# 1901 Reviews
# Data Scientist- Bangalore
# Trigent Software
# 3.8
# 309 Reviews
# Analytics Senior Analyst - Artificial Intelligence Innovation
# Accenture
# 4.1
# 35560 Reviews
# Analytics Analyst - Artificial Intelligence Innovation
# Accenture
# 4.1
# 35560 Reviews
# Research Specialist
# Accenture
# 4.1
# 35560 Reviews
# Opportunity | Data Scientist | Tavant India
# Tavant Technologies
# 4.1
# 406 Reviews
# Data Scientist
# ...

# %%
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_240")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b91342b450a63710b678a55cbc41bd", element="D894A26C696766872EBA641B177D279E_element_241")>,
# ...

# %%
driver.page_source
# Out:
# '<html lang="en"><head><title>Data Scientist Jobs, 867 Data Scientist Job Vacancies In May 2023 - Naukri.com</title><meta name="description" content="Apply To 867 Data Scientist Jobs On Naukri.com, #1 Job Portal In India. Explore Data Scientist Job Openings In Your Desired Locations Now!"><link rel="alternate" href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs"><link rel="canonical" href="https://www.naukri.com/data-scientist-jobs"><meta name="atdlayout" content="jobsearch"><meta name="robots" content="ALL"><meta name="classification" content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs"><meta name="pragma" content="no-cache"><meta name="rating" content="general"><meta name="revisit-after" content="1 day"><meta name="distribution" content="GLOBAL"><meta name="resource-type" content="document"><meta name="author" content="www.naukri.com"><meta name="content-language" content="EN"><meta property="fb:app_id" content="171330469593307"><meta n
# ...

# %%
for i in new:
    print(i.text)
# Out:
# Data Science Specialist
# Data Scientist - R/Python
# Data Scientist_NLP
# Data Science Analyst - Data Science
# Data Science Analyst Data Science
# Analytics Specialist - Artificial Intelligence Innovation
# Senior Data Scientist
# 0-3 Lakhs
# 3-6 Lakhs
# 6-10 Lakhs
# 10-15 Lakhs
# Data Scientist, Engineering at Google
# Machine Learning (AI) Architect
# Data Scientist- Bangalore
# Bangalore/Bengaluru
# Delhi / NCR
# Hyderabad/Secunderabad
# Mumbai (All Areas)
# Analytics Senior Analyst - Artificial Intelligence Innovation
# Analytics Analyst - Artificial Intelligence Innovation
# Research Specialist
# Opportunity | Data Scientist | Tavant India
# Data Scientist
# Data Scientist II
# Accenture
# IBM
# Adidas
# Paypal
# Senior Manager I, Data Science
# Sr. Data Scientist
# Data Scientist @ Heritage Foods Ltd, HYD.
# Data Scientist
